# %% [markdown]
# ### Minha Playlist

# %%
print("Playlist")
minha_lista = ["The clansman - Iron Maiden", "Daytona - CrisMJ", "Ponte Bonita - CrisMJ", "Altar - Hulvey", "I feel so good today - Charlie Brown Jr."]
print(minha_lista[0])
print(minha_lista[1])
print(minha_lista[2])
print(minha_lista[3])
print(minha_lista[4])
# Out:
# Playlist
# The clansman - Iron Maiden
# Daytona - CrisMJ
# Ponte Bonita - CrisMJ
# Altar - Hulvey
# I feel so good today - Charlie Brown Jr.
