# %% [markdown]
# ### Looping For

# %%
for numero in range(17):
    print(numero)

# %%
imunes = ['Nicolas', 'Pedro', 'Motoboy', 'Raivosa', 'Yasmin vou estudar pra etec', 'Dre Dre', 'André faz programa', 'Larissa Manu', 'Inominável(Ar)', 'Alemão', 'Gnomo', 'Breno Tcholinha C#', 'Rodrigo pipa combate', 'Expulso do curso, mas voltou', 'Yasmin Smurfete']


for nome_imune in imunes: 
    print(nome_imune)
# Out:
# Nicolas
# Pedro
# Motoboy
# Raivosa
# Yasmin vou estudar pra etec
# Dre Dre
# André faz programa
# Larissa Manu
# Inominável(Ar)
# Alemão
# Gnomo
# Breno Tcholinha C#
# Rodrigo pipa combate
# Expulso do curso, mas voltou
# Yasmin Smurfete

# %%
for numero in range(100):
    pergunta = input("Pedro você é tcholão?")

# %% [markdown]
# ### While

# %%
while True:
    pergunta = input("Pedro você é tcholão?")
    if pergunta == "sim":
        print("Já sabia, kkk")
        break
# Out:
# Já sabia, kkk

# %% [markdown]
# ### Crush

# %%
while True:
    pergunta = input("Qual o nome do seu Crush ou Crusha??")
    if pergunta == "Mãe do Fulano":
        print("Tá certinho, a mãe da um caldo")
        break
# Out:
# Tá certinho, a mãe da um caldo
